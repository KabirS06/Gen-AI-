# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %% [markdown]
# # AutoGrad (used for complex differnetial equations)
# ## What is AutoGrad?
# ### AutoGrad is a core concept of PyTorch that provides automatic differentiation for tensor operations. It enables gradient computations , which is essentials for training machine learning models using optimization like gradient descent

# %%
x=torch.tensor(2.0,requires_grad=True)

# %%
y=(x**3)+(2*(x**2))+(5*x)

# %%
z=torch.sin(y)

# %%
x
# Out:
# tensor(2., requires_grad=True)

# %%
y
# Out:
# tensor(26., grad_fn=<AddBackward0>)

# %%
z
# Out:
# tensor(0.7626, grad_fn=<SinBackward0>)

# %%
# To calculate dz/dx
z.backward()

# %%
x.grad # gives value of dz/dx at x
# Out:
# tensor(16.1730)

# %%
# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0)  # Weight
b = torch.tensor(0.0)  # Bias

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass
z = w * x + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %%
# USing AutoGrad to make it easier
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z=w*x+b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss=binary_cross_entropy_loss(y_pred,y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
y=(x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearding Grad
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad # repetitive backward and forward causes grad to accumulate
# Out:
# tensor(8.)

# %%
# Clearing Grad
x.grad.zero_()
# Out:
# tensor(0.)

# %%
#Disabling Gradient Tracking (done when model predicts some value)
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
#option 1: requires_grad_(false)
#option 2: detach()
#option 3: torch.no_grad()

# %%
#Option1: requires Grad
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x # no Require Grad in output
# Out:
# tensor(2.)

# %%
y=x**2 # no grad fnc in output
y
# Out:
# tensor(4.)

# %%
 y.backward() # hence no grad
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_539/1700767986.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# ...

# %%
## option 2 : detach (creating new tenosr)
z=x.detach()
z
# Out:
# tensor(2.)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1=z**2
y1
# Out:
# tensor(4.)

# %%
# option 3 : calling No grad
with torch.no_grad():
  y=x**2

# %%
y
# Out:
# tensor(4.)
